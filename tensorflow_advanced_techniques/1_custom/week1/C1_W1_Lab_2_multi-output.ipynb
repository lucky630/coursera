# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %%
norm_train_X.shape , train_Y[1].shape
# Out:
# ((614, 8), (614,))

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
inp = Input(shape=(norm_train_X.shape[1],))
first = Dense(128,activation='relu')(inp)
second = Dense(128,activation='relu')(first)

# Y1 output will be fed directly from the second dense
out1 = Dense(1,name='y1_out')(second)
third = Dense(64,activation='relu')(second)

# Y2 output will come via the third dense
out2 = Dense(1,name='y2_out')(third)

# Define the model with the input layer and a list of output layers
model = Model(inputs=[inp],outputs=[out1,out2])
print(model.summary())
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 128)          1152        input_3[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 128)          16512       dense_6[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 64)           8256        dense_7[0][0]
# __________________________________________________________________________________________________
# y1_out (Dense)                  (None, 1)            129         dense_7[0][0]
# __________________________________________________________________________________________________
# y2_out (Dense)                  (None, 1)            65          dense_8[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
from tensorflow.python.keras.utils.vis_utils import plot_model

# %%
plot_model(model)

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_out': 'mse', 'y2_out': 'mse'},
              metrics={'y1_out': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_out': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 1ms/sample - loss: 242.7747 - y1_out_loss: 114.1463 - y2_out_loss: 126.3152 - y1_out_root_mean_squared_error: 10.7347 - y2_out_root_mean_squared_error: 11.2934 - val_loss: 33.3242 - val_y1_out_loss: 12.0568 - val_y2_out_loss: 20.3106 - val_y1_out_root_mean_squared_error: 3.5151 - val_y2_out_root_mean_squared_error: 4.5791
# Epoch 2/500
# 614/614 [==============================] - 0s 140us/sample - loss: 31.7653 - y1_out_loss: 12.4458 - y2_out_loss: 19.2863 - y1_out_root_mean_squared_error: 3.5405 - y2_out_root_mean_squared_error: 4.3852 - val_loss: 28.8590 - val_y1_out_loss: 10.0748 - val_y2_out_loss: 18.7618 - val_y1_out_root_mean_squared_error: 3.1980 - val_y2_out_root_mean_squared_error: 4.3164
# Epoch 3/500
# 614/614 [==============================] - 0s 141us/sample - loss: 25.7604 - y1_out_loss: 10.2254 - y2_out_loss: 15.4658 - y1_out_root_mean_squared_error: 3.2036 - y2_out_root_mean_squared_error: 3.9367 - val_loss: 24.2001 - val_y1_out_loss: 9.2830 - val_y2_out_loss: 14.3663 - val_y1_out_root_mean_squared_error: 3.0661 - val_y2_out_root_mean_squared_error: 3.8469
# Epoch 4/500
# 614/614 [==============================] - 0s 134us/sample - loss: 32.8940 - y1_out_loss: 10.9201 - y2_out_loss: 21.8184 - y1_out_root_mean_squared_error: 3.3180 - y2_out_root_mean_squared_error: 4.6781 - val_loss: 20.1134 - val_y1_out_loss: 8.5244 - val_y2_out_loss: 11.9684 - val_y1_out_root_mean_squared_error: 2.8824 - val_y2_out_root_mean_squared_error: 3.4359
# Epoch 5/500
# 614/614 [==============================] - 0s 133us/sample - loss: 21.5785 - y1_out_loss: 8.8868 - y2_out_loss: 12.9840 - y1_out_root_mean_squared_error: 2.9877 - y2_out_root_mean_squared_error: 3.5570 - val_loss: 36.2461 - val_y1_out_loss: 11.2303 - val_y2_out_loss: 25.6775 - val_y1_out_root_mean_squared_error: 3.3287 - val_y2_out_root_mean_squared_error: 5.0166
# Epoch 6/500
# 614/614 [==============================] - 0s 126us/sample - loss: 23.5602 - y1_out_loss: 9.1101 - y2_out_loss: 14.8576 - y1_out_root_mean_squared_error: 3.0063 - y2_out_root_mean_squared_error: 3.8108 - val_loss: 98.5063 - val_y1_out_loss: 17.5396 - val_y2_out_loss: 84.8658 - val_y1_out_root_mean_squared_error: 4.0778 - val_y2_out_root_mean_squared_error: 9.0486
# Epoch 7/500
# 614/614 [==============================] - 0s 134us/sample - loss: 24.2237 - y1_out_loss: 8.8743 - y2_out_loss: 15.2160 - y1_out_root_mean_squared_error: 2.9866 - y2_out_root_mean_squared_error: 3.9120 - val_loss: 25.6443 - val_y1_out_loss: 9.7011 - val_y2_out_loss: 15.3077 - val_y1_out_root_mean_squared_error: 3.1370 - val_y2_out_root_mean_squared_error: 3.9753
# Epoch 8/500
# 614/614 [==============================] - 0s 131us/sample - loss: 26.5888 - y1_out_loss: 9.8092 - y2_out_loss: 16.6388 - y1_out_root_mean_squared_error: 3.1321 - y2_out_root_mean_squared_error: 4.0962 - val_loss: 23.3746 - val_y1_out_loss: 11.0790 - val_y2_out_loss: 13.3886 - val_y1_out_root_mean_squared_error: 3.2287 - val_y2_out_root_mean_squared_error: 3.5986
# Epoch 9/500
# 614/614 [==============================] - 0s 132us/sample - loss: 22.1629 - y1_out_loss: 8.4948 - y2_out_loss: 13.8575 - y1_out_root_mean_squared_error: 2.9071 - y2_out_root_mean_squared_error: 3.7030 - val_loss: 31.9985 - val_y1_out_loss: 9.5699 - val_y2_out_loss: 21.7414 - val_y1_out_root_mean_squared_error: 3.1234 - val_y2_out_root_mean_squared_error: 4.7162
# Epoch 10/500
# 614/614 [==============================] - 0s 125us/sample - loss: 21.9362 - y1_out_loss: 8.7198 - y2_out_loss: 13.4916 - y1_out_root_mean_squared_error: 2.9266 - y2_out_root_mean_squared_error: 3.6567 - val_loss: 50.9800 - val_y1_out_loss: 14.7049 - val_y2_out_loss: 34.9051 - val_y1_out_root_mean_squared_error: 3.8990 - val_y2_out_root_mean_squared_error: 5.9815
# Epoch 11/500
# 614/614 [==============================] - 0s 130us/sample - loss: 23.2154 - y1_out_loss: 8.5099 - y2_out_loss: 14.5729 - y1_out_root_mean_squared_error: 2.9274 - y2_out_root_mean_squared_error: 3.8270 - val_loss: 48.2786 - val_y1_out_loss: 12.2572 - val_y2_out_loss: 37.8710 - val_y1_out_root_mean_squared_error: 3.4146 - val_y2_out_root_mean_squared_error: 6.0514
# Epoch 12/500
# 614/614 [==============================] - 0s 131us/sample - loss: 19.4732 - y1_out_loss: 7.7300 - y2_out_loss: 11.6774 - y1_out_root_mean_squared_error: 2.7855 - y2_out_root_mean_squared_error: 3.4226 - val_loss: 20.6947 - val_y1_out_loss: 8.0953 - val_y2_out_loss: 12.3040 - val_y1_out_root_mean_squared_error: 2.8454 - val_y2_out_root_mean_squared_error: 3.5495
# Epoch 13/500
# 614/614 [==============================] - 0s 131us/sample - loss: 21.7914 - y1_out_loss: 8.3926 - y2_out_loss: 13.2898 - y1_out_root_mean_squared_error: 2.9001 - y2_out_root_mean_squared_error: 3.6580 - val_loss: 18.8840 - val_y1_out_loss: 8.8196 - val_y2_out_loss: 10.7022 - val_y1_out_root_mean_squared_error: 2.9043 - val_y2_out_root_mean_squared_error: 3.2324
# Epoch 14/500
# 614/614 [==============================] - 0s 132us/sample - loss: 19.6452 - y1_out_loss: 7.6093 - y2_out_loss: 12.0432 - y1_out_root_mean_squared_error: 2.7694 - y2_out_root_mean_squared_error: 3.4606 - val_loss: 17.7898 - val_y1_out_loss: 6.8124 - val_y2_out_loss: 10.8660 - val_y1_out_root_mean_squared_error: 2.5955 - val_y2_out_root_mean_squared_error: 3.3246
# Epoch 15/500
# 614/614 [==============================] - 0s 129us/sample - loss: 18.3140 - y1_out_loss: 7.0448 - y2_out_loss: 11.1111 - y1_out_root_mean_squared_error: 2.6651 - y2_out_root_mean_squared_error: 3.3483 - val_loss: 15.3425 - val_y1_out_loss: 6.6933 - val_y2_out_loss: 8.8980 - val_y1_out_root_mean_squared_error: 2.5476 - val_y2_out_root_mean_squared_error: 2.9753
# Epoch 16/500
# 614/614 [==============================] - 0s 128us/sample - loss: 18.2620 - y1_out_loss: 7.0928 - y2_out_loss: 11.1385 - y1_out_root_mean_squared_error: 2.6554 - y2_out_root_mean_squared_error: 3.3483 - val_loss: 14.7029 - val_y1_out_loss: 6.3841 - val_y2_out_loss: 8.6951 - val_y1_out_root_mean_squared_error: 2.4770 - val_y2_out_root_mean_squared_error: 2.9270
# Epoch 17/500
# 614/614 [==============================] - 0s 132us/sample - loss: 15.8998 - y1_out_loss: 6.5245 - y2_out_loss: 9.3795 - y1_out_root_mean_squared_error: 2.5399 - y2_out_root_mean_squared_error: 3.0739 - val_loss: 14.9195 - val_y1_out_loss: 6.9446 - val_y2_out_loss: 8.4563 - val_y1_out_root_mean_squared_error: 2.5702 - val_y2_out_root_mean_squared_error: 2.8833
# Epoch 18/500
# 614/614 [==============================] - 0s 132us/sample - loss: 16.5280 - y1_out_loss: 6.5472 - y2_out_loss: 9.8676 - y1_out_root_mean_squared_error: 2.5689 - y2_out_root_mean_squared_error: 3.1510 - val_loss: 14.5852 - val_y1_out_loss: 6.3019 - val_y2_out_loss: 8.5649 - val_y1_out_root_mean_squared_error: 2.4720 - val_y2_out_root_mean_squared_error: 2.9111
# Epoch 19/500
# 614/614 [==============================] - 0s 134us/sample - loss: 16.8421 - y1_out_loss: 6.1085 - y2_out_loss: 10.7054 - y1_out_root_mean_squared_error: 2.4761 - y2_out_root_mean_squared_error: 3.2728 - val_loss: 22.3453 - val_y1_out_loss: 6.7081 - val_y2_out_loss: 16.4256 - val_y1_out_root_mean_squared_error: 2.5304 - val_y2_out_root_mean_squared_error: 3.9928
# Epoch 20/500
# 614/614 [==============================] - 0s 128us/sample - loss: 15.4351 - y1_out_loss: 6.0445 - y2_out_loss: 9.3701 - y1_out_root_mean_squared_error: 2.4494 - y2_out_root_mean_squared_error: 3.0717 - val_loss: 21.4617 - val_y1_out_loss: 8.0036 - val_y2_out_loss: 13.1849 - val_y1_out_root_mean_squared_error: 2.8476 - val_y2_out_root_mean_squared_error: 3.6541
# Epoch 21/500
# 614/614 [==============================] - 0s 120us/sample - loss: 15.0920 - y1_out_loss: 5.5901 - y2_out_loss: 9.4954 - y1_out_root_mean_squared_error: 2.3503 - y2_out_root_mean_squared_error: 3.0932 - val_loss: 13.0701 - val_y1_out_loss: 5.6372 - val_y2_out_loss: 7.7524 - val_y1_out_root_mean_squared_error: 2.3400 - val_y2_out_root_mean_squared_error: 2.7558
# Epoch 22/500
# 614/614 [==============================] - 0s 132us/sample - loss: 14.3532 - y1_out_loss: 5.4346 - y2_out_loss: 8.7986 - y1_out_root_mean_squared_error: 2.3415 - y2_out_root_mean_squared_error: 2.9783 - val_loss: 21.4851 - val_y1_out_loss: 7.5153 - val_y2_out_loss: 13.5932 - val_y1_out_root_mean_squared_error: 2.7593 - val_y2_out_root_mean_squared_error: 3.7244
# Epoch 23/500
# 614/614 [==============================] - 0s 133us/sample - loss: 15.5418 - y1_out_loss: 5.5212 - y2_out_loss: 9.9320 - y1_out_root_mean_squared_error: 2.3500 - y2_out_root_mean_squared_error: 3.1653 - val_loss: 12.9706 - val_y1_out_loss: 5.5358 - val_y2_out_loss: 7.6881 - val_y1_out_root_mean_squared_error: 2.3152 - val_y2_out_root_mean_squared_error: 2.7587
# Epoch 24/500
# 614/614 [==============================] - 0s 128us/sample - loss: 13.5938 - y1_out_loss: 5.3049 - y2_out_loss: 8.2029 - y1_out_root_mean_squared_error: 2.3099 - y2_out_root_mean_squared_error: 2.8737 - val_loss: 11.8624 - val_y1_out_loss: 5.0493 - val_y2_out_loss: 7.1282 - val_y1_out_root_mean_squared_error: 2.1968 - val_y2_out_root_mean_squared_error: 2.6526
# Epoch 25/500
# 614/614 [==============================] - 0s 128us/sample - loss: 20.7060 - y1_out_loss: 6.9592 - y2_out_loss: 13.5721 - y1_out_root_mean_squared_error: 2.6505 - y2_out_root_mean_squared_error: 3.6988 - val_loss: 13.9966 - val_y1_out_loss: 5.4213 - val_y2_out_loss: 9.3003 - val_y1_out_root_mean_squared_error: 2.2487 - val_y2_out_root_mean_squared_error: 2.9900
# Epoch 26/500
# 614/614 [==============================] - 0s 130us/sample - loss: 14.1675 - y1_out_loss: 5.1981 - y2_out_loss: 8.8685 - y1_out_root_mean_squared_error: 2.2887 - y2_out_root_mean_squared_error: 2.9882 - val_loss: 11.6274 - val_y1_out_loss: 4.9215 - val_y2_out_loss: 7.0774 - val_y1_out_root_mean_squared_error: 2.1794 - val_y2_out_root_mean_squared_error: 2.6225
# Epoch 27/500
# 614/614 [==============================] - 0s 130us/sample - loss: 13.7258 - y1_out_loss: 5.0485 - y2_out_loss: 8.6073 - y1_out_root_mean_squared_error: 2.2518 - y2_out_root_mean_squared_error: 2.9420 - val_loss: 12.0783 - val_y1_out_loss: 4.5516 - val_y2_out_loss: 8.1650 - val_y1_out_root_mean_squared_error: 2.0705 - val_y2_out_root_mean_squared_error: 2.7913
# Epoch 28/500
# 614/614 [==============================] - 0s 129us/sample - loss: 14.0972 - y1_out_loss: 4.8558 - y2_out_loss: 9.1531 - y1_out_root_mean_squared_error: 2.2117 - y2_out_root_mean_squared_error: 3.0341 - val_loss: 10.9164 - val_y1_out_loss: 4.5518 - val_y2_out_loss: 6.6361 - val_y1_out_root_mean_squared_error: 2.0914 - val_y2_out_root_mean_squared_error: 2.5578
# Epoch 29/500
# 614/614 [==============================] - 0s 131us/sample - loss: 11.9097 - y1_out_loss: 4.3472 - y2_out_loss: 7.4578 - y1_out_root_mean_squared_error: 2.0931 - y2_out_root_mean_squared_error: 2.7438 - val_loss: 11.5058 - val_y1_out_loss: 4.8397 - val_y2_out_loss: 6.8018 - val_y1_out_root_mean_squared_error: 2.1737 - val_y2_out_root_mean_squared_error: 2.6040
# Epoch 30/500
# 614/614 [==============================] - 0s 140us/sample - loss: 11.8515 - y1_out_loss: 4.2440 - y2_out_loss: 7.5219 - y1_out_root_mean_squared_error: 2.0695 - y2_out_root_mean_squared_error: 2.7511 - val_loss: 12.3159 - val_y1_out_loss: 5.0583 - val_y2_out_loss: 7.8715 - val_y1_out_root_mean_squared_error: 2.1860 - val_y2_out_root_mean_squared_error: 2.7454
# Epoch 31/500
# 614/614 [==============================] - 0s 133us/sample - loss: 11.6994 - y1_out_loss: 4.0694 - y2_out_loss: 7.5866 - y1_out_root_mean_squared_error: 2.0250 - y2_out_root_mean_squared_error: 2.7566 - val_loss: 15.0999 - val_y1_out_loss: 4.7788 - val_y2_out_loss: 11.0616 - val_y1_out_root_mean_squared_error: 2.1149 - val_y2_out_root_mean_squared_error: 3.2599
# Epoch 32/500
# 614/614 [==============================] - 0s 126us/sample - loss: 11.8584 - y1_out_loss: 4.3036 - y2_out_loss: 7.5650 - y1_out_root_mean_squared_error: 2.0796 - y2_out_root_mean_squared_error: 2.7447 - val_loss: 11.0074 - val_y1_out_loss: 4.7653 - val_y2_out_loss: 6.7606 - val_y1_out_root_mean_squared_error: 2.1334 - val_y2_out_root_mean_squared_error: 2.5409
# Epoch 33/500
# 614/614 [==============================] - 0s 130us/sample - loss: 11.2819 - y1_out_loss: 3.9959 - y2_out_loss: 7.3287 - y1_out_root_mean_squared_error: 2.0057 - y2_out_root_mean_squared_error: 2.6943 - val_loss: 31.0276 - val_y1_out_loss: 6.9159 - val_y2_out_loss: 25.3176 - val_y1_out_root_mean_squared_error: 2.5446 - val_y2_out_root_mean_squared_error: 4.9551
# Epoch 34/500
# 614/614 [==============================] - 0s 123us/sample - loss: 10.0099 - y1_out_loss: 3.6773 - y2_out_loss: 6.3652 - y1_out_root_mean_squared_error: 1.9139 - y2_out_root_mean_squared_error: 2.5193 - val_loss: 12.9596 - val_y1_out_loss: 4.1645 - val_y2_out_loss: 8.8211 - val_y1_out_root_mean_squared_error: 2.0256 - val_y2_out_root_mean_squared_error: 2.9760
# Epoch 35/500
# 614/614 [==============================] - 0s 137us/sample - loss: 9.5812 - y1_out_loss: 3.1603 - y2_out_loss: 6.4194 - y1_out_root_mean_squared_error: 1.7841 - y2_out_root_mean_squared_error: 2.5295 - val_loss: 9.9326 - val_y1_out_loss: 3.6173 - val_y2_out_loss: 6.8546 - val_y1_out_root_mean_squared_error: 1.8356 - val_y2_out_root_mean_squared_error: 2.5619
# Epoch 36/500
# 614/614 [==============================] - 0s 134us/sample - loss: 9.7094 - y1_out_loss: 3.2404 - y2_out_loss: 6.3888 - y1_out_root_mean_squared_error: 1.8074 - y2_out_root_mean_squared_error: 2.5383 - val_loss: 8.2209 - val_y1_out_loss: 3.3579 - val_y2_out_loss: 5.1576 - val_y1_out_root_mean_squared_error: 1.7951 - val_y2_out_root_mean_squared_error: 2.2358
# Epoch 37/500
# 614/614 [==============================] - 0s 122us/sample - loss: 8.7502 - y1_out_loss: 3.1636 - y2_out_loss: 5.5548 - y1_out_root_mean_squared_error: 1.7809 - y2_out_root_mean_squared_error: 2.3619 - val_loss: 7.8017 - val_y1_out_loss: 3.2377 - val_y2_out_loss: 4.8423 - val_y1_out_root_mean_squared_error: 1.7304 - val_y2_out_root_mean_squared_error: 2.1926
# Epoch 38/500
# 614/614 [==============================] - 0s 133us/sample - loss: 11.6817 - y1_out_loss: 3.8214 - y2_out_loss: 7.7540 - y1_out_root_mean_squared_error: 1.9630 - y2_out_root_mean_squared_error: 2.7979 - val_loss: 7.8072 - val_y1_out_loss: 2.8750 - val_y2_out_loss: 4.9594 - val_y1_out_root_mean_squared_error: 1.6770 - val_y2_out_root_mean_squared_error: 2.2349
# Epoch 39/500
# 614/614 [==============================] - 0s 133us/sample - loss: 9.0804 - y1_out_loss: 3.1549 - y2_out_loss: 5.8879 - y1_out_root_mean_squared_error: 1.7838 - y2_out_root_mean_squared_error: 2.4287 - val_loss: 11.4872 - val_y1_out_loss: 3.1513 - val_y2_out_loss: 8.9163 - val_y1_out_root_mean_squared_error: 1.7056 - val_y2_out_root_mean_squared_error: 2.9288
# Epoch 40/500
# 614/614 [==============================] - 0s 130us/sample - loss: 8.1118 - y1_out_loss: 2.8855 - y2_out_loss: 5.2272 - y1_out_root_mean_squared_error: 1.6993 - y2_out_root_mean_squared_error: 2.2856 - val_loss: 11.0196 - val_y1_out_loss: 3.0014 - val_y2_out_loss: 8.2225 - val_y1_out_root_mean_squared_error: 1.7029 - val_y2_out_root_mean_squared_error: 2.8495
# Epoch 41/500
# 614/614 [==============================] - 0s 130us/sample - loss: 8.7451 - y1_out_loss: 2.8746 - y2_out_loss: 5.8433 - y1_out_root_mean_squared_error: 1.6904 - y2_out_root_mean_squared_error: 2.4264 - val_loss: 6.7084 - val_y1_out_loss: 2.6323 - val_y2_out_loss: 4.3221 - val_y1_out_root_mean_squared_error: 1.5687 - val_y2_out_root_mean_squared_error: 2.0610
# Epoch 42/500
# 614/614 [==============================] - 0s 128us/sample - loss: 8.4567 - y1_out_loss: 2.6212 - y2_out_loss: 5.9242 - y1_out_root_mean_squared_error: 1.6073 - y2_out_root_mean_squared_error: 2.4234 - val_loss: 8.5574 - val_y1_out_loss: 3.1658 - val_y2_out_loss: 5.3282 - val_y1_out_root_mean_squared_error: 1.7849 - val_y2_out_root_mean_squared_error: 2.3176
# Epoch 43/500
# 614/614 [==============================] - 0s 130us/sample - loss: 7.8755 - y1_out_loss: 2.5563 - y2_out_loss: 5.2873 - y1_out_root_mean_squared_error: 1.6043 - y2_out_root_mean_squared_error: 2.3026 - val_loss: 7.9215 - val_y1_out_loss: 2.4534 - val_y2_out_loss: 5.8174 - val_y1_out_root_mean_squared_error: 1.5086 - val_y2_out_root_mean_squared_error: 2.3761
# Epoch 44/500
# 614/614 [==============================] - 0s 132us/sample - loss: 8.2955 - y1_out_loss: 2.5414 - y2_out_loss: 5.6898 - y1_out_root_mean_squared_error: 1.6012 - y2_out_root_mean_squared_error: 2.3941 - val_loss: 6.2741 - val_y1_out_loss: 2.2511 - val_y2_out_loss: 4.2222 - val_y1_out_root_mean_squared_error: 1.4644 - val_y2_out_root_mean_squared_error: 2.0322
# Epoch 45/500
# 614/614 [==============================] - 0s 131us/sample - loss: 7.9022 - y1_out_loss: 2.5070 - y2_out_loss: 5.5273 - y1_out_root_mean_squared_error: 1.5696 - y2_out_root_mean_squared_error: 2.3321 - val_loss: 15.8041 - val_y1_out_loss: 3.9828 - val_y2_out_loss: 11.7130 - val_y1_out_root_mean_squared_error: 2.0075 - val_y2_out_root_mean_squared_error: 3.4313
# Epoch 46/500
# 614/614 [==============================] - 0s 132us/sample - loss: 7.4078 - y1_out_loss: 2.2085 - y2_out_loss: 5.2391 - y1_out_root_mean_squared_error: 1.4814 - y2_out_root_mean_squared_error: 2.2833 - val_loss: 6.3043 - val_y1_out_loss: 2.4052 - val_y2_out_loss: 4.1929 - val_y1_out_root_mean_squared_error: 1.4913 - val_y2_out_root_mean_squared_error: 2.0200
# Epoch 47/500
# 614/614 [==============================] - 0s 136us/sample - loss: 7.9772 - y1_out_loss: 2.5852 - y2_out_loss: 5.3986 - y1_out_root_mean_squared_error: 1.6059 - y2_out_root_mean_squared_error: 2.3234 - val_loss: 6.2268 - val_y1_out_loss: 2.0874 - val_y2_out_loss: 4.1651 - val_y1_out_root_mean_squared_error: 1.4330 - val_y2_out_root_mean_squared_error: 2.0429
# Epoch 48/500
# 614/614 [==============================] - 0s 123us/sample - loss: 8.1095 - y1_out_loss: 2.4244 - y2_out_loss: 5.7015 - y1_out_root_mean_squared_error: 1.5577 - y2_out_root_mean_squared_error: 2.3839 - val_loss: 7.8194 - val_y1_out_loss: 3.1134 - val_y2_out_loss: 4.7552 - val_y1_out_root_mean_squared_error: 1.7368 - val_y2_out_root_mean_squared_error: 2.1915
# Epoch 49/500
# 614/614 [==============================] - 0s 129us/sample - loss: 10.3170 - y1_out_loss: 2.9477 - y2_out_loss: 7.3890 - y1_out_root_mean_squared_error: 1.7155 - y2_out_root_mean_squared_error: 2.7155 - val_loss: 14.1279 - val_y1_out_loss: 4.2283 - val_y2_out_loss: 10.5805 - val_y1_out_root_mean_squared_error: 1.9754 - val_y2_out_root_mean_squared_error: 3.1978
# Epoch 50/500
# 614/614 [==============================] - 0s 130us/sample - loss: 8.2639 - y1_out_loss: 2.6531 - y2_out_loss: 5.5965 - y1_out_root_mean_squared_error: 1.6331 - y2_out_root_mean_squared_error: 2.3658 - val_loss: 6.5007 - val_y1_out_loss: 1.9976 - val_y2_out_loss: 4.7566 - val_y1_out_root_mean_squared_error: 1.3716 - val_y2_out_root_mean_squared_error: 2.1492
# Epoch 51/500
# 614/614 [==============================] - 0s 127us/sample - loss: 6.6775 - y1_out_loss: 1.9811 - y2_out_loss: 4.6869 - y1_out_root_mean_squared_error: 1.4085 - y2_out_root_mean_squared_error: 2.1664 - val_loss: 9.1507 - val_y1_out_loss: 3.0906 - val_y2_out_loss: 6.0982 - val_y1_out_root_mean_squared_error: 1.7561 - val_y2_out_root_mean_squared_error: 2.4631
# Epoch 52/500
# 614/614 [==============================] - 0s 124us/sample - loss: 9.6278 - y1_out_loss: 2.8274 - y2_out_loss: 6.8548 - y1_out_root_mean_squared_error: 1.6818 - y2_out_root_mean_squared_error: 2.6076 - val_loss: 8.2022 - val_y1_out_loss: 3.0790 - val_y2_out_loss: 5.5601 - val_y1_out_root_mean_squared_error: 1.7001 - val_y2_out_root_mean_squared_error: 2.3048
# Epoch 53/500
# 614/614 [==============================] - 0s 128us/sample - loss: 7.6713 - y1_out_loss: 2.2867 - y2_out_loss: 5.3336 - y1_out_root_mean_squared_error: 1.5179 - y2_out_root_mean_squared_error: 2.3167 - val_loss: 5.1915 - val_y1_out_loss: 1.7674 - val_y2_out_loss: 3.6097 - val_y1_out_root_mean_squared_error: 1.2802 - val_y2_out_root_mean_squared_error: 1.8849
# Epoch 54/500
# 614/614 [==============================] - 0s 128us/sample - loss: 6.1892 - y1_out_loss: 1.7477 - y2_out_loss: 4.4719 - y1_out_root_mean_squared_error: 1.3217 - y2_out_root_mean_squared_error: 2.1077 - val_loss: 9.0844 - val_y1_out_loss: 2.6751 - val_y2_out_loss: 6.8092 - val_y1_out_root_mean_squared_error: 1.5726 - val_y2_out_root_mean_squared_error: 2.5713
# Epoch 55/500
# 614/614 [==============================] - 0s 129us/sample - loss: 6.4079 - y1_out_loss: 1.7485 - y2_out_loss: 4.6975 - y1_out_root_mean_squared_error: 1.3234 - y2_out_root_mean_squared_error: 2.1579 - val_loss: 29.0702 - val_y1_out_loss: 7.2429 - val_y2_out_loss: 23.1624 - val_y1_out_root_mean_squared_error: 2.5850 - val_y2_out_root_mean_squared_error: 4.7316
# Epoch 56/500
# 614/614 [==============================] - 0s 120us/sample - loss: 7.2226 - y1_out_loss: 1.8610 - y2_out_loss: 5.3235 - y1_out_root_mean_squared_error: 1.3652 - y2_out_root_mean_squared_error: 2.3149 - val_loss: 5.0074 - val_y1_out_loss: 1.7337 - val_y2_out_loss: 3.3978 - val_y1_out_root_mean_squared_error: 1.2679 - val_y2_out_root_mean_squared_error: 1.8438
# Epoch 57/500
# 614/614 [==============================] - 0s 126us/sample - loss: 6.0046 - y1_out_loss: 1.8330 - y2_out_loss: 4.1812 - y1_out_root_mean_squared_error: 1.3523 - y2_out_root_mean_squared_error: 2.0435 - val_loss: 8.2534 - val_y1_out_loss: 1.5017 - val_y2_out_loss: 6.6458 - val_y1_out_root_mean_squared_error: 1.2087 - val_y2_out_root_mean_squared_error: 2.6062
# Epoch 58/500
# 614/614 [==============================] - 0s 126us/sample - loss: 6.4680 - y1_out_loss: 1.7529 - y2_out_loss: 4.7531 - y1_out_root_mean_squared_error: 1.3298 - y2_out_root_mean_squared_error: 2.1679 - val_loss: 10.0642 - val_y1_out_loss: 2.0207 - val_y2_out_loss: 8.3727 - val_y1_out_root_mean_squared_error: 1.3707 - val_y2_out_root_mean_squared_error: 2.8610
# Epoch 59/500
# 614/614 [==============================] - 0s 130us/sample - loss: 9.9788 - y1_out_loss: 2.9941 - y2_out_loss: 6.9539 - y1_out_root_mean_squared_error: 1.7362 - y2_out_root_mean_squared_error: 2.6390 - val_loss: 8.2924 - val_y1_out_loss: 1.9256 - val_y2_out_loss: 6.5212 - val_y1_out_root_mean_squared_error: 1.3617 - val_y2_out_root_mean_squared_error: 2.5374
# Epoch 60/500
# 614/614 [==============================] - 0s 134us/sample - loss: 7.1551 - y1_out_loss: 2.0566 - y2_out_loss: 5.1189 - y1_out_root_mean_squared_error: 1.4237 - y2_out_root_mean_squared_error: 2.2646 - val_loss: 6.5003 - val_y1_out_loss: 1.6659 - val_y2_out_loss: 4.7742 - val_y1_out_root_mean_squared_error: 1.2873 - val_y2_out_root_mean_squared_error: 2.2007
# Epoch 61/500
# 614/614 [==============================] - 0s 132us/sample - loss: 32.9421 - y1_out_loss: 11.7262 - y2_out_loss: 20.9284 - y1_out_root_mean_squared_error: 3.4395 - y2_out_root_mean_squared_error: 4.5948 - val_loss: 12.3972 - val_y1_out_loss: 5.0763 - val_y2_out_loss: 7.3147 - val_y1_out_root_mean_squared_error: 2.2406 - val_y2_out_root_mean_squared_error: 2.7161
# Epoch 62/500
# 614/614 [==============================] - 0s 122us/sample - loss: 7.4271 - y1_out_loss: 2.1274 - y2_out_loss: 5.2354 - y1_out_root_mean_squared_error: 1.4639 - y2_out_root_mean_squared_error: 2.2987 - val_loss: 5.5976 - val_y1_out_loss: 1.8309 - val_y2_out_loss: 3.9166 - val_y1_out_root_mean_squared_error: 1.3159 - val_y2_out_root_mean_squared_error: 1.9663
# Epoch 63/500
# 614/614 [==============================] - 0s 135us/sample - loss: 4.7284 - y1_out_loss: 1.2580 - y2_out_loss: 3.5506 - y1_out_root_mean_squared_error: 1.1262 - y2_out_root_mean_squared_error: 1.8601 - val_loss: 22.0820 - val_y1_out_loss: 4.1197 - val_y2_out_loss: 18.6535 - val_y1_out_root_mean_squared_error: 1.9611 - val_y2_out_root_mean_squared_error: 4.2704
# Epoch 64/500
# 614/614 [==============================] - 0s 135us/sample - loss: 6.9535 - y1_out_loss: 1.8445 - y2_out_loss: 5.0900 - y1_out_root_mean_squared_error: 1.3578 - y2_out_root_mean_squared_error: 2.2605 - val_loss: 5.2323 - val_y1_out_loss: 1.7347 - val_y2_out_loss: 3.6412 - val_y1_out_root_mean_squared_error: 1.2741 - val_y2_out_root_mean_squared_error: 1.8998
# Epoch 65/500
# 614/614 [==============================] - 0s 136us/sample - loss: 5.6121 - y1_out_loss: 1.4685 - y2_out_loss: 4.1145 - y1_out_root_mean_squared_error: 1.2149 - y2_out_root_mean_squared_error: 2.0338 - val_loss: 7.2833 - val_y1_out_loss: 2.0056 - val_y2_out_loss: 5.5395 - val_y1_out_root_mean_squared_error: 1.3688 - val_y2_out_root_mean_squared_error: 2.3259
# Epoch 66/500
# 614/614 [==============================] - 0s 133us/sample - loss: 7.6770 - y1_out_loss: 2.1694 - y2_out_loss: 5.5729 - y1_out_root_mean_squared_error: 1.4787 - y2_out_root_mean_squared_error: 2.3432 - val_loss: 7.6229 - val_y1_out_loss: 1.7226 - val_y2_out_loss: 6.2917 - val_y1_out_root_mean_squared_error: 1.2432 - val_y2_out_root_mean_squared_error: 2.4652
# Epoch 67/500
# 614/614 [==============================] - 0s 129us/sample - loss: 9.5150 - y1_out_loss: 2.7697 - y2_out_loss: 6.7353 - y1_out_root_mean_squared_error: 1.6633 - y2_out_root_mean_squared_error: 2.5977 - val_loss: 10.0041 - val_y1_out_loss: 2.4172 - val_y2_out_loss: 7.3993 - val_y1_out_root_mean_squared_error: 1.5756 - val_y2_out_root_mean_squared_error: 2.7425
# Epoch 68/500
# 614/614 [==============================] - 0s 133us/sample - loss: 5.0319 - y1_out_loss: 1.3514 - y2_out_loss: 3.6419 - y1_out_root_mean_squared_error: 1.1673 - y2_out_root_mean_squared_error: 1.9155 - val_loss: 4.3537 - val_y1_out_loss: 1.2890 - val_y2_out_loss: 3.1427 - val_y1_out_root_mean_squared_error: 1.1084 - val_y2_out_root_mean_squared_error: 1.7678
# Epoch 69/500
# 614/614 [==============================] - 0s 133us/sample - loss: 4.9247 - y1_out_loss: 1.2237 - y2_out_loss: 3.6573 - y1_out_root_mean_squared_error: 1.1109 - y2_out_root_mean_squared_error: 1.9211 - val_loss: 4.4636 - val_y1_out_loss: 1.3972 - val_y2_out_loss: 3.1733 - val_y1_out_root_mean_squared_error: 1.1485 - val_y2_out_root_mean_squared_error: 1.7733
# Epoch 70/500
# 614/614 [==============================] - 0s 133us/sample - loss: 4.5393 - y1_out_loss: 1.0279 - y2_out_loss: 3.5078 - y1_out_root_mean_squared_error: 1.0131 - y2_out_root_mean_squared_error: 1.8743 - val_loss: 8.3294 - val_y1_out_loss: 1.0060 - val_y2_out_loss: 7.2424 - val_y1_out_root_mean_squared_error: 0.9965 - val_y2_out_root_mean_squared_error: 2.7086
# Epoch 71/500
# 614/614 [==============================] - 0s 133us/sample - loss: 4.7365 - y1_out_loss: 1.1041 - y2_out_loss: 3.6035 - y1_out_root_mean_squared_error: 1.0550 - y2_out_root_mean_squared_error: 1.9035 - val_loss: 5.1677 - val_y1_out_loss: 1.2149 - val_y2_out_loss: 3.8587 - val_y1_out_root_mean_squared_error: 1.1062 - val_y2_out_root_mean_squared_error: 1.9859
# Epoch 72/500
# 614/614 [==============================] - 0s 136us/sample - loss: 5.9189 - y1_out_loss: 1.3991 - y2_out_loss: 4.5837 - y1_out_root_mean_squared_error: 1.1826 - y2_out_root_mean_squared_error: 2.1261 - val_loss: 5.2646 - val_y1_out_loss: 1.5865 - val_y2_out_loss: 3.7667 - val_y1_out_root_mean_squared_error: 1.2247 - val_y2_out_root_mean_squared_error: 1.9403
# Epoch 73/500
# 614/614 [==============================] - 0s 121us/sample - loss: 5.4396 - y1_out_loss: 1.3580 - y2_out_loss: 4.0825 - y1_out_root_mean_squared_error: 1.1655 - y2_out_root_mean_squared_error: 2.0202 - val_loss: 3.3889 - val_y1_out_loss: 0.8235 - val_y2_out_loss: 2.5851 - val_y1_out_root_mean_squared_error: 0.8840 - val_y2_out_root_mean_squared_error: 1.6147
# Epoch 74/500
# 614/614 [==============================] - 0s 135us/sample - loss: 5.0641 - y1_out_loss: 1.1563 - y2_out_loss: 3.8673 - y1_out_root_mean_squared_error: 1.0785 - y2_out_root_mean_squared_error: 1.9751 - val_loss: 4.0084 - val_y1_out_loss: 1.1692 - val_y2_out_loss: 2.8857 - val_y1_out_root_mean_squared_error: 1.0471 - val_y2_out_root_mean_squared_error: 1.7064
# Epoch 75/500
# 614/614 [==============================] - 0s 140us/sample - loss: 5.0881 - y1_out_loss: 1.3962 - y2_out_loss: 3.6926 - y1_out_root_mean_squared_error: 1.1807 - y2_out_root_mean_squared_error: 1.9220 - val_loss: 3.9546 - val_y1_out_loss: 1.1050 - val_y2_out_loss: 2.9471 - val_y1_out_root_mean_squared_error: 1.0100 - val_y2_out_root_mean_squared_error: 1.7130
# Epoch 76/500
# 614/614 [==============================] - 0s 135us/sample - loss: 4.7836 - y1_out_loss: 1.1646 - y2_out_loss: 3.5967 - y1_out_root_mean_squared_error: 1.0813 - y2_out_root_mean_squared_error: 1.9012 - val_loss: 3.9604 - val_y1_out_loss: 0.8623 - val_y2_out_loss: 3.0656 - val_y1_out_root_mean_squared_error: 0.9257 - val_y2_out_root_mean_squared_error: 1.7616
# Epoch 77/500
# 614/614 [==============================] - 0s 134us/sample - loss: 3.3872 - y1_out_loss: 0.7468 - y2_out_loss: 2.6274 - y1_out_root_mean_squared_error: 0.8641 - y2_out_root_mean_squared_error: 1.6250 - val_loss: 4.9943 - val_y1_out_loss: 0.8052 - val_y2_out_loss: 4.1318 - val_y1_out_root_mean_squared_error: 0.8941 - val_y2_out_root_mean_squared_error: 2.0481
# Epoch 78/500
# 614/614 [==============================] - 0s 141us/sample - loss: 4.2495 - y1_out_loss: 0.9553 - y2_out_loss: 3.3172 - y1_out_root_mean_squared_error: 0.9801 - y2_out_root_mean_squared_error: 1.8135 - val_loss: 4.3902 - val_y1_out_loss: 0.8742 - val_y2_out_loss: 3.5406 - val_y1_out_root_mean_squared_error: 0.9151 - val_y2_out_root_mean_squared_error: 1.8849
# Epoch 79/500
# 614/614 [==============================] - 0s 126us/sample - loss: 3.6835 - y1_out_loss: 0.8380 - y2_out_loss: 2.8296 - y1_out_root_mean_squared_error: 0.9196 - y2_out_root_mean_squared_error: 1.6846 - val_loss: 5.6423 - val_y1_out_loss: 1.4144 - val_y2_out_loss: 4.3167 - val_y1_out_root_mean_squared_error: 1.1532 - val_y2_out_root_mean_squared_error: 2.0766
# Epoch 80/500
# 614/614 [==============================] - 0s 131us/sample - loss: 3.3171 - y1_out_loss: 0.7367 - y2_out_loss: 2.6217 - y1_out_root_mean_squared_error: 0.8593 - y2_out_root_mean_squared_error: 1.6058 - val_loss: 11.5288 - val_y1_out_loss: 1.1253 - val_y2_out_loss: 10.4440 - val_y1_out_root_mean_squared_error: 1.0376 - val_y2_out_root_mean_squared_error: 3.2330
# Epoch 81/500
# 614/614 [==============================] - 0s 135us/sample - loss: 5.0016 - y1_out_loss: 1.0504 - y2_out_loss: 3.9455 - y1_out_root_mean_squared_error: 1.0217 - y2_out_root_mean_squared_error: 1.9894 - val_loss: 3.9750 - val_y1_out_loss: 1.0951 - val_y2_out_loss: 2.7828 - val_y1_out_root_mean_squared_error: 1.0606 - val_y2_out_root_mean_squared_error: 1.6883
# Epoch 82/500
# 614/614 [==============================] - 0s 134us/sample - loss: 4.8515 - y1_out_loss: 1.0407 - y2_out_loss: 3.8262 - y1_out_root_mean_squared_error: 1.0232 - y2_out_root_mean_squared_error: 1.9505 - val_loss: 3.2384 - val_y1_out_loss: 0.6230 - val_y2_out_loss: 2.6127 - val_y1_out_root_mean_squared_error: 0.7720 - val_y2_out_root_mean_squared_error: 1.6256
# Epoch 83/500
# 614/614 [==============================] - 0s 137us/sample - loss: 3.7083 - y1_out_loss: 0.8157 - y2_out_loss: 2.8668 - y1_out_root_mean_squared_error: 0.9060 - y2_out_root_mean_squared_error: 1.6993 - val_loss: 3.0891 - val_y1_out_loss: 0.5909 - val_y2_out_loss: 2.4365 - val_y1_out_root_mean_squared_error: 0.7681 - val_y2_out_root_mean_squared_error: 1.5809
# Epoch 84/500
# 614/614 [==============================] - 0s 135us/sample - loss: 3.4580 - y1_out_loss: 0.8735 - y2_out_loss: 2.5571 - y1_out_root_mean_squared_error: 0.9386 - y2_out_root_mean_squared_error: 1.6053 - val_loss: 3.1910 - val_y1_out_loss: 0.6961 - val_y2_out_loss: 2.5268 - val_y1_out_root_mean_squared_error: 0.8020 - val_y2_out_root_mean_squared_error: 1.5962
# Epoch 85/500
# 614/614 [==============================] - 0s 124us/sample - loss: 3.9571 - y1_out_loss: 0.8035 - y2_out_loss: 3.1264 - y1_out_root_mean_squared_error: 0.8988 - y2_out_root_mean_squared_error: 1.7746 - val_loss: 2.8935 - val_y1_out_loss: 0.4865 - val_y2_out_loss: 2.3690 - val_y1_out_root_mean_squared_error: 0.6833 - val_y2_out_root_mean_squared_error: 1.5578
# Epoch 86/500
# 614/614 [==============================] - 0s 135us/sample - loss: 13.5385 - y1_out_loss: 3.6967 - y2_out_loss: 9.7471 - y1_out_root_mean_squared_error: 1.9267 - y2_out_root_mean_squared_error: 3.1347 - val_loss: 8.0176 - val_y1_out_loss: 2.6302 - val_y2_out_loss: 5.2901 - val_y1_out_root_mean_squared_error: 1.6343 - val_y2_out_root_mean_squared_error: 2.3123
# Epoch 87/500
# 614/614 [==============================] - 0s 138us/sample - loss: 3.7983 - y1_out_loss: 0.8159 - y2_out_loss: 2.9694 - y1_out_root_mean_squared_error: 0.9068 - y2_out_root_mean_squared_error: 1.7251 - val_loss: 4.5096 - val_y1_out_loss: 1.0077 - val_y2_out_loss: 3.6100 - val_y1_out_root_mean_squared_error: 0.9616 - val_y2_out_root_mean_squared_error: 1.8934
# Epoch 88/500
# 614/614 [==============================] - 0s 141us/sample - loss: 5.5909 - y1_out_loss: 1.2827 - y2_out_loss: 4.2732 - y1_out_root_mean_squared_error: 1.1354 - y2_out_root_mean_squared_error: 2.0741 - val_loss: 4.2448 - val_y1_out_loss: 0.9777 - val_y2_out_loss: 3.1695 - val_y1_out_root_mean_squared_error: 1.0011 - val_y2_out_root_mean_squared_error: 1.8007
# Epoch 89/500
# 614/614 [==============================] - 0s 139us/sample - loss: 3.5192 - y1_out_loss: 0.7522 - y2_out_loss: 2.7927 - y1_out_root_mean_squared_error: 0.8706 - y2_out_root_mean_squared_error: 1.6617 - val_loss: 4.3320 - val_y1_out_loss: 0.6521 - val_y2_out_loss: 3.7276 - val_y1_out_root_mean_squared_error: 0.7812 - val_y2_out_root_mean_squared_error: 1.9292
# Epoch 90/500
# 614/614 [==============================] - 0s 134us/sample - loss: 5.0377 - y1_out_loss: 0.9774 - y2_out_loss: 4.0651 - y1_out_root_mean_squared_error: 0.9901 - y2_out_root_mean_squared_error: 2.0143 - val_loss: 7.4356 - val_y1_out_loss: 1.5439 - val_y2_out_loss: 5.9809 - val_y1_out_root_mean_squared_error: 1.2145 - val_y2_out_root_mean_squared_error: 2.4415
# Epoch 91/500
# 614/614 [==============================] - 0s 122us/sample - loss: 3.4148 - y1_out_loss: 0.6604 - y2_out_loss: 2.7611 - y1_out_root_mean_squared_error: 0.8159 - y2_out_root_mean_squared_error: 1.6581 - val_loss: 4.4231 - val_y1_out_loss: 0.5340 - val_y2_out_loss: 3.9010 - val_y1_out_root_mean_squared_error: 0.7118 - val_y2_out_root_mean_squared_error: 1.9790
# Epoch 92/500
# 614/614 [==============================] - 0s 134us/sample - loss: 4.8156 - y1_out_loss: 1.0410 - y2_out_loss: 3.7395 - y1_out_root_mean_squared_error: 1.0207 - y2_out_root_mean_squared_error: 1.9426 - val_loss: 3.2999 - val_y1_out_loss: 0.6750 - val_y2_out_loss: 2.6483 - val_y1_out_root_mean_squared_error: 0.7944 - val_y2_out_root_mean_squared_error: 1.6336
# Epoch 93/500
# 614/614 [==============================] - 0s 136us/sample - loss: 3.8200 - y1_out_loss: 0.7685 - y2_out_loss: 3.0423 - y1_out_root_mean_squared_error: 0.8756 - y2_out_root_mean_squared_error: 1.7474 - val_loss: 4.1252 - val_y1_out_loss: 1.1071 - val_y2_out_loss: 2.9249 - val_y1_out_root_mean_squared_error: 1.0634 - val_y2_out_root_mean_squared_error: 1.7305
# Epoch 94/500
# 614/614 [==============================] - 0s 136us/sample - loss: 6.7325 - y1_out_loss: 1.7875 - y2_out_loss: 4.9564 - y1_out_root_mean_squared_error: 1.3323 - y2_out_root_mean_squared_error: 2.2265 - val_loss: 8.0569 - val_y1_out_loss: 2.3810 - val_y2_out_loss: 5.4222 - val_y1_out_root_mean_squared_error: 1.5665 - val_y2_out_root_mean_squared_error: 2.3670
# Epoch 95/500
# 614/614 [==============================] - 0s 138us/sample - loss: 4.6981 - y1_out_loss: 1.2005 - y2_out_loss: 3.4984 - y1_out_root_mean_squared_error: 1.0962 - y2_out_root_mean_squared_error: 1.8699 - val_loss: 3.8724 - val_y1_out_loss: 0.7629 - val_y2_out_loss: 3.0442 - val_y1_out_root_mean_squared_error: 0.8782 - val_y2_out_root_mean_squared_error: 1.7610
# Epoch 96/500
# 614/614 [==============================] - 0s 134us/sample - loss: 3.0508 - y1_out_loss: 0.5923 - y2_out_loss: 2.4638 - y1_out_root_mean_squared_error: 0.7674 - y2_out_root_mean_squared_error: 1.5691 - val_loss: 2.5579 - val_y1_out_loss: 0.5680 - val_y2_out_loss: 1.9904 - val_y1_out_root_mean_squared_error: 0.7246 - val_y2_out_root_mean_squared_error: 1.4258
# Epoch 97/500
# 614/614 [==============================] - 0s 127us/sample - loss: 3.3628 - y1_out_loss: 0.7007 - y2_out_loss: 2.6442 - y1_out_root_mean_squared_error: 0.8341 - y2_out_root_mean_squared_error: 1.6331 - val_loss: 4.4598 - val_y1_out_loss: 1.0464 - val_y2_out_loss: 3.4249 - val_y1_out_root_mean_squared_error: 1.0171 - val_y2_out_root_mean_squared_error: 1.8507
# Epoch 98/500
# 614/614 [==============================] - 0s 135us/sample - loss: 3.4501 - y1_out_loss: 0.7787 - y2_out_loss: 2.6740 - y1_out_root_mean_squared_error: 0.8844 - y2_out_root_mean_squared_error: 1.6334 - val_loss: 2.7195 - val_y1_out_loss: 0.6808 - val_y2_out_loss: 2.0299 - val_y1_out_root_mean_squared_error: 0.7932 - val_y2_out_root_mean_squared_error: 1.4458
# Epoch 99/500
# 614/614 [==============================] - 0s 136us/sample - loss: 2.7198 - y1_out_loss: 0.5752 - y2_out_loss: 2.1837 - y1_out_root_mean_squared_error: 0.7598 - y2_out_root_mean_squared_error: 1.4637 - val_loss: 5.1990 - val_y1_out_loss: 1.6195 - val_y2_out_loss: 3.6537 - val_y1_out_root_mean_squared_error: 1.2584 - val_y2_out_root_mean_squared_error: 1.9014
# Epoch 100/500
# 614/614 [==============================] - 0s 136us/sample - loss: 3.0198 - y1_out_loss: 0.6776 - y2_out_loss: 2.3607 - y1_out_root_mean_squared_error: 0.8233 - y2_out_root_mean_squared_error: 1.5303 - val_loss: 4.0689 - val_y1_out_loss: 1.1093 - val_y2_out_loss: 2.9558 - val_y1_out_root_mean_squared_error: 1.0353 - val_y2_out_root_mean_squared_error: 1.7312
# Epoch 101/500
# 614/614 [==============================] - 0s 140us/sample - loss: 3.0605 - y1_out_loss: 0.6685 - y2_out_loss: 2.3939 - y1_out_root_mean_squared_error: 0.8174 - y2_out_root_mean_squared_error: 1.5467 - val_loss: 6.9094 - val_y1_out_loss: 1.1591 - val_y2_out_loss: 5.7716 - val_y1_out_root_mean_squared_error: 1.0594 - val_y2_out_root_mean_squared_error: 2.4056
# Epoch 102/500
# 614/614 [==============================] - 0s 134us/sample - loss: 4.0611 - y1_out_loss: 0.9952 - y2_out_loss: 3.1231 - y1_out_root_mean_squared_error: 0.9723 - y2_out_root_mean_squared_error: 1.7652 - val_loss: 6.1800 - val_y1_out_loss: 1.1851 - val_y2_out_loss: 4.8717 - val_y1_out_root_mean_squared_error: 1.0688 - val_y2_out_root_mean_squared_error: 2.2445
# Epoch 103/500
# 614/614 [==============================] - 0s 121us/sample - loss: 4.1011 - y1_out_loss: 0.9545 - y2_out_loss: 3.1404 - y1_out_root_mean_squared_error: 0.9768 - y2_out_root_mean_squared_error: 1.7740 - val_loss: 6.9316 - val_y1_out_loss: 2.2628 - val_y2_out_loss: 4.9093 - val_y1_out_root_mean_squared_error: 1.4796 - val_y2_out_root_mean_squared_error: 2.1777
# Epoch 104/500
# 614/614 [==============================] - 0s 141us/sample - loss: 3.3597 - y1_out_loss: 0.6959 - y2_out_loss: 2.6356 - y1_out_root_mean_squared_error: 0.8374 - y2_out_root_mean_squared_error: 1.6305 - val_loss: 2.7574 - val_y1_out_loss: 0.5774 - val_y2_out_loss: 2.1469 - val_y1_out_root_mean_squared_error: 0.7604 - val_y2_out_root_mean_squared_error: 1.4762
# Epoch 105/500
# 614/614 [==============================] - 0s 132us/sample - loss: 2.5451 - y1_out_loss: 0.4913 - y2_out_loss: 2.0365 - y1_out_root_mean_squared_error: 0.7024 - y2_out_root_mean_squared_error: 1.4324 - val_loss: 3.3646 - val_y1_out_loss: 0.7985 - val_y2_out_loss: 2.4740 - val_y1_out_root_mean_squared_error: 0.9064 - val_y2_out_root_mean_squared_error: 1.5947
# Epoch 106/500
# 614/614 [==============================] - 0s 138us/sample - loss: 3.0031 - y1_out_loss: 0.5772 - y2_out_loss: 2.4102 - y1_out_root_mean_squared_error: 0.7622 - y2_out_root_mean_squared_error: 1.5563 - val_loss: 5.5281 - val_y1_out_loss: 0.8727 - val_y2_out_loss: 4.5696 - val_y1_out_root_mean_squared_error: 0.9490 - val_y2_out_root_mean_squared_error: 2.1512
# Epoch 107/500
# 614/614 [==============================] - 0s 137us/sample - loss: 2.6615 - y1_out_loss: 0.5381 - y2_out_loss: 2.1405 - y1_out_root_mean_squared_error: 0.7320 - y2_out_root_mean_squared_error: 1.4580 - val_loss: 2.7145 - val_y1_out_loss: 0.5282 - val_y2_out_loss: 2.1310 - val_y1_out_root_mean_squared_error: 0.7264 - val_y2_out_root_mean_squared_error: 1.4788
# Epoch 108/500
# 614/614 [==============================] - 0s 138us/sample - loss: 3.8042 - y1_out_loss: 0.8753 - y2_out_loss: 2.9527 - y1_out_root_mean_squared_error: 0.9278 - y2_out_root_mean_squared_error: 1.7156 - val_loss: 8.6958 - val_y1_out_loss: 3.4244 - val_y2_out_loss: 5.4949 - val_y1_out_root_mean_squared_error: 1.8050 - val_y2_out_root_mean_squared_error: 2.3319
# Epoch 109/500
# 614/614 [==============================] - 0s 123us/sample - loss: 2.8821 - y1_out_loss: 0.6983 - y2_out_loss: 2.1921 - y1_out_root_mean_squared_error: 0.8375 - y2_out_root_mean_squared_error: 1.4767 - val_loss: 7.8800 - val_y1_out_loss: 1.3048 - val_y2_out_loss: 6.7003 - val_y1_out_root_mean_squared_error: 1.1067 - val_y2_out_root_mean_squared_error: 2.5798
# Epoch 110/500
# 614/614 [==============================] - 0s 133us/sample - loss: 4.5805 - y1_out_loss: 0.9128 - y2_out_loss: 3.6506 - y1_out_root_mean_squared_error: 0.9571 - y2_out_root_mean_squared_error: 1.9143 - val_loss: 3.1481 - val_y1_out_loss: 0.8398 - val_y2_out_loss: 2.2629 - val_y1_out_root_mean_squared_error: 0.9043 - val_y2_out_root_mean_squared_error: 1.5265
# Epoch 111/500
# 614/614 [==============================] - 0s 135us/sample - loss: 3.0111 - y1_out_loss: 0.7158 - y2_out_loss: 2.3014 - y1_out_root_mean_squared_error: 0.8460 - y2_out_root_mean_squared_error: 1.5151 - val_loss: 2.7888 - val_y1_out_loss: 0.6962 - val_y2_out_loss: 2.0959 - val_y1_out_root_mean_squared_error: 0.8126 - val_y2_out_root_mean_squared_error: 1.4589
# Epoch 112/500
# 614/614 [==============================] - 0s 137us/sample - loss: 3.8883 - y1_out_loss: 0.8990 - y2_out_loss: 2.9824 - y1_out_root_mean_squared_error: 0.9475 - y2_out_root_mean_squared_error: 1.7293 - val_loss: 4.1917 - val_y1_out_loss: 0.7719 - val_y2_out_loss: 3.3936 - val_y1_out_root_mean_squared_error: 0.8811 - val_y2_out_root_mean_squared_error: 1.8481
# Epoch 113/500
# 614/614 [==============================] - 0s 137us/sample - loss: 2.6385 - y1_out_loss: 0.5239 - y2_out_loss: 2.1250 - y1_out_root_mean_squared_error: 0.7237 - y2_out_root_mean_squared_error: 1.4542 - val_loss: 7.3820 - val_y1_out_loss: 0.5290 - val_y2_out_loss: 6.7442 - val_y1_out_root_mean_squared_error: 0.7217 - val_y2_out_root_mean_squared_error: 2.6194
# Epoch 114/500
# 614/614 [==============================] - 0s 134us/sample - loss: 2.8767 - y1_out_loss: 0.5086 - y2_out_loss: 2.3604 - y1_out_root_mean_squared_error: 0.7153 - y2_out_root_mean_squared_error: 1.5379 - val_loss: 4.2670 - val_y1_out_loss: 0.6758 - val_y2_out_loss: 3.6072 - val_y1_out_root_mean_squared_error: 0.7981 - val_y2_out_root_mean_squared_error: 1.9052
# Epoch 115/500
# 614/614 [==============================] - 0s 121us/sample - loss: 3.2716 - y1_out_loss: 0.7537 - y2_out_loss: 2.4928 - y1_out_root_mean_squared_error: 0.8705 - y2_out_root_mean_squared_error: 1.5855 - val_loss: 2.2045 - val_y1_out_loss: 0.4684 - val_y2_out_loss: 1.6889 - val_y1_out_root_mean_squared_error: 0.6852 - val_y2_out_root_mean_squared_error: 1.3172
# Epoch 116/500
# 614/614 [==============================] - 0s 132us/sample - loss: 2.9521 - y1_out_loss: 0.5851 - y2_out_loss: 2.3599 - y1_out_root_mean_squared_error: 0.7595 - y2_out_root_mean_squared_error: 1.5412 - val_loss: 3.3947 - val_y1_out_loss: 0.4935 - val_y2_out_loss: 2.8867 - val_y1_out_root_mean_squared_error: 0.7058 - val_y2_out_root_mean_squared_error: 1.7019
# Epoch 117/500
# 614/614 [==============================] - 0s 134us/sample - loss: 4.3385 - y1_out_loss: 1.1542 - y2_out_loss: 3.1459 - y1_out_root_mean_squared_error: 1.0793 - y2_out_root_mean_squared_error: 1.7815 - val_loss: 3.1505 - val_y1_out_loss: 0.5626 - val_y2_out_loss: 2.5569 - val_y1_out_root_mean_squared_error: 0.7553 - val_y2_out_root_mean_squared_error: 1.6062
# Epoch 118/500
# 614/614 [==============================] - 0s 140us/sample - loss: 2.5063 - y1_out_loss: 0.4550 - y2_out_loss: 2.0407 - y1_out_root_mean_squared_error: 0.6716 - y2_out_root_mean_squared_error: 1.4336 - val_loss: 3.4424 - val_y1_out_loss: 0.8783 - val_y2_out_loss: 2.5041 - val_y1_out_root_mean_squared_error: 0.9469 - val_y2_out_root_mean_squared_error: 1.5955
# Epoch 119/500
# 614/614 [==============================] - 0s 128us/sample - loss: 4.2938 - y1_out_loss: 1.0540 - y2_out_loss: 3.2048 - y1_out_root_mean_squared_error: 1.0307 - y2_out_root_mean_squared_error: 1.7976 - val_loss: 2.2196 - val_y1_out_loss: 0.5123 - val_y2_out_loss: 1.6720 - val_y1_out_root_mean_squared_error: 0.7063 - val_y2_out_root_mean_squared_error: 1.3118
# Epoch 120/500
# 614/614 [==============================] - 0s 126us/sample - loss: 2.8117 - y1_out_loss: 0.5526 - y2_out_loss: 2.2453 - y1_out_root_mean_squared_error: 0.7455 - y2_out_root_mean_squared_error: 1.5020 - val_loss: 2.2339 - val_y1_out_loss: 0.5674 - val_y2_out_loss: 1.6584 - val_y1_out_root_mean_squared_error: 0.7247 - val_y2_out_root_mean_squared_error: 1.3072
# Epoch 121/500
# 614/614 [==============================] - 0s 135us/sample - loss: 2.3846 - y1_out_loss: 0.5122 - y2_out_loss: 1.8547 - y1_out_root_mean_squared_error: 0.7189 - y2_out_root_mean_squared_error: 1.3667 - val_loss: 2.2498 - val_y1_out_loss: 0.4558 - val_y2_out_loss: 1.7585 - val_y1_out_root_mean_squared_error: 0.6645 - val_y2_out_root_mean_squared_error: 1.3447
# Epoch 122/500
# 614/614 [==============================] - 0s 136us/sample - loss: 2.7867 - y1_out_loss: 0.6165 - y2_out_loss: 2.1648 - y1_out_root_mean_squared_error: 0.7816 - y2_out_root_mean_squared_error: 1.4750 - val_loss: 3.2075 - val_y1_out_loss: 0.6227 - val_y2_out_loss: 2.6401 - val_y1_out_root_mean_squared_error: 0.7521 - val_y2_out_root_mean_squared_error: 1.6254
# Epoch 123/500
# 614/614 [==============================] - 0s 133us/sample - loss: 2.9405 - y1_out_loss: 0.5387 - y2_out_loss: 2.3922 - y1_out_root_mean_squared_error: 0.7359 - y2_out_root_mean_squared_error: 1.5489 - val_loss: 2.2434 - val_y1_out_loss: 0.3983 - val_y2_out_loss: 1.7847 - val_y1_out_root_mean_squared_error: 0.6347 - val_y2_out_root_mean_squared_error: 1.3567
# Epoch 124/500
# 614/614 [==============================] - 0s 133us/sample - loss: 2.1351 - y1_out_loss: 0.4507 - y2_out_loss: 1.6988 - y1_out_root_mean_squared_error: 0.6741 - y2_out_root_mean_squared_error: 1.2964 - val_loss: 4.1794 - val_y1_out_loss: 0.5056 - val_y2_out_loss: 3.6090 - val_y1_out_root_mean_squared_error: 0.7179 - val_y2_out_root_mean_squared_error: 1.9141
# Epoch 125/500
# 614/614 [==============================] - 0s 143us/sample - loss: 2.3598 - y1_out_loss: 0.4516 - y2_out_loss: 1.8943 - y1_out_root_mean_squared_error: 0.6723 - y2_out_root_mean_squared_error: 1.3813 - val_loss: 2.4539 - val_y1_out_loss: 0.6450 - val_y2_out_loss: 1.7678 - val_y1_out_root_mean_squared_error: 0.7981 - val_y2_out_root_mean_squared_error: 1.3479
# Epoch 126/500
# 614/614 [==============================] - 0s 121us/sample - loss: 3.0480 - y1_out_loss: 0.6038 - y2_out_loss: 2.4351 - y1_out_root_mean_squared_error: 0.7788 - y2_out_root_mean_squared_error: 1.5625 - val_loss: 2.6280 - val_y1_out_loss: 0.4660 - val_y2_out_loss: 2.1185 - val_y1_out_root_mean_squared_error: 0.6596 - val_y2_out_root_mean_squared_error: 1.4808
# Epoch 127/500
# 614/614 [==============================] - 0s 134us/sample - loss: 3.1013 - y1_out_loss: 0.5671 - y2_out_loss: 2.5488 - y1_out_root_mean_squared_error: 0.7558 - y2_out_root_mean_squared_error: 1.5906 - val_loss: 4.5612 - val_y1_out_loss: 0.6621 - val_y2_out_loss: 3.9720 - val_y1_out_root_mean_squared_error: 0.8099 - val_y2_out_root_mean_squared_error: 1.9762
# Epoch 128/500
# ...
# Epoch 459/500
# 614/614 [==============================] - 0s 120us/sample - loss: 0.4483 - y1_out_loss: 0.1212 - y2_out_loss: 0.3293 - y1_out_root_mean_squared_error: 0.3479 - y2_out_root_mean_squared_error: 0.5720 - val_loss: 1.4463 - val_y1_out_loss: 0.3035 - val_y2_out_loss: 1.1301 - val_y1_out_root_mean_squared_error: 0.5545 - val_y2_out_root_mean_squared_error: 1.0672
# Epoch 460/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.4447 - y1_out_loss: 0.1078 - y2_out_loss: 0.3390 - y1_out_root_mean_squared_error: 0.3294 - y2_out_root_mean_squared_error: 0.5798 - val_loss: 1.0479 - val_y1_out_loss: 0.3618 - val_y2_out_loss: 0.7187 - val_y1_out_root_mean_squared_error: 0.5695 - val_y2_out_root_mean_squared_error: 0.8506
# Epoch 461/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.6620 - y1_out_loss: 0.1458 - y2_out_loss: 0.5128 - y1_out_root_mean_squared_error: 0.3835 - y2_out_root_mean_squared_error: 0.7176 - val_loss: 0.7618 - val_y1_out_loss: 0.2670 - val_y2_out_loss: 0.5067 - val_y1_out_root_mean_squared_error: 0.4997 - val_y2_out_root_mean_squared_error: 0.7156
# Epoch 462/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.4308 - y1_out_loss: 0.1115 - y2_out_loss: 0.3286 - y1_out_root_mean_squared_error: 0.3292 - y2_out_root_mean_squared_error: 0.5678 - val_loss: 0.9841 - val_y1_out_loss: 0.3378 - val_y2_out_loss: 0.6543 - val_y1_out_root_mean_squared_error: 0.5641 - val_y2_out_root_mean_squared_error: 0.8160
# Epoch 463/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.7155 - y1_out_loss: 0.1436 - y2_out_loss: 0.5680 - y1_out_root_mean_squared_error: 0.3799 - y2_out_root_mean_squared_error: 0.7557 - val_loss: 0.7243 - val_y1_out_loss: 0.2662 - val_y2_out_loss: 0.4595 - val_y1_out_root_mean_squared_error: 0.5068 - val_y2_out_root_mean_squared_error: 0.6837
# Epoch 464/500
# 614/614 [==============================] - 0s 124us/sample - loss: 0.5566 - y1_out_loss: 0.1110 - y2_out_loss: 0.4415 - y1_out_root_mean_squared_error: 0.3345 - y2_out_root_mean_squared_error: 0.6669 - val_loss: 0.7665 - val_y1_out_loss: 0.2861 - val_y2_out_loss: 0.4875 - val_y1_out_root_mean_squared_error: 0.5204 - val_y2_out_root_mean_squared_error: 0.7040
# Epoch 465/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.4203 - y1_out_loss: 0.1097 - y2_out_loss: 0.3097 - y1_out_root_mean_squared_error: 0.3326 - y2_out_root_mean_squared_error: 0.5565 - val_loss: 0.9549 - val_y1_out_loss: 0.2824 - val_y2_out_loss: 0.6618 - val_y1_out_root_mean_squared_error: 0.5342 - val_y2_out_root_mean_squared_error: 0.8182
# Epoch 466/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.4464 - y1_out_loss: 0.1104 - y2_out_loss: 0.3324 - y1_out_root_mean_squared_error: 0.3337 - y2_out_root_mean_squared_error: 0.5788 - val_loss: 0.7450 - val_y1_out_loss: 0.2787 - val_y2_out_loss: 0.4725 - val_y1_out_root_mean_squared_error: 0.5108 - val_y2_out_root_mean_squared_error: 0.6958
# Epoch 467/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.4678 - y1_out_loss: 0.1173 - y2_out_loss: 0.3471 - y1_out_root_mean_squared_error: 0.3429 - y2_out_root_mean_squared_error: 0.5918 - val_loss: 0.7493 - val_y1_out_loss: 0.2705 - val_y2_out_loss: 0.4796 - val_y1_out_root_mean_squared_error: 0.5111 - val_y2_out_root_mean_squared_error: 0.6986
# Epoch 468/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.4504 - y1_out_loss: 0.1156 - y2_out_loss: 0.3345 - y1_out_root_mean_squared_error: 0.3402 - y2_out_root_mean_squared_error: 0.5785 - val_loss: 0.9896 - val_y1_out_loss: 0.3140 - val_y2_out_loss: 0.6822 - val_y1_out_root_mean_squared_error: 0.5474 - val_y2_out_root_mean_squared_error: 0.8307
# Epoch 469/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.4620 - y1_out_loss: 0.1246 - y2_out_loss: 0.3365 - y1_out_root_mean_squared_error: 0.3534 - y2_out_root_mean_squared_error: 0.5806 - val_loss: 1.1255 - val_y1_out_loss: 0.3097 - val_y2_out_loss: 0.8332 - val_y1_out_root_mean_squared_error: 0.5399 - val_y2_out_root_mean_squared_error: 0.9132
# Epoch 470/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.5207 - y1_out_loss: 0.1325 - y2_out_loss: 0.3852 - y1_out_root_mean_squared_error: 0.3645 - y2_out_root_mean_squared_error: 0.6228 - val_loss: 0.8695 - val_y1_out_loss: 0.3157 - val_y2_out_loss: 0.5752 - val_y1_out_root_mean_squared_error: 0.5389 - val_y2_out_root_mean_squared_error: 0.7610
# Epoch 471/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.5649 - y1_out_loss: 0.1203 - y2_out_loss: 0.4416 - y1_out_root_mean_squared_error: 0.3481 - y2_out_root_mean_squared_error: 0.6661 - val_loss: 0.7728 - val_y1_out_loss: 0.2691 - val_y2_out_loss: 0.5204 - val_y1_out_root_mean_squared_error: 0.4999 - val_y2_out_root_mean_squared_error: 0.7231
# Epoch 472/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.3670 - y1_out_loss: 0.1019 - y2_out_loss: 0.2632 - y1_out_root_mean_squared_error: 0.3197 - y2_out_root_mean_squared_error: 0.5146 - val_loss: 0.6976 - val_y1_out_loss: 0.2785 - val_y2_out_loss: 0.4431 - val_y1_out_root_mean_squared_error: 0.5064 - val_y2_out_root_mean_squared_error: 0.6642
# Epoch 473/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.4407 - y1_out_loss: 0.1155 - y2_out_loss: 0.3271 - y1_out_root_mean_squared_error: 0.3392 - y2_out_root_mean_squared_error: 0.5706 - val_loss: 0.8716 - val_y1_out_loss: 0.3035 - val_y2_out_loss: 0.5682 - val_y1_out_root_mean_squared_error: 0.5532 - val_y2_out_root_mean_squared_error: 0.7521
# Epoch 474/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.4557 - y1_out_loss: 0.1194 - y2_out_loss: 0.3450 - y1_out_root_mean_squared_error: 0.3423 - y2_out_root_mean_squared_error: 0.5818 - val_loss: 1.1984 - val_y1_out_loss: 0.3724 - val_y2_out_loss: 0.8078 - val_y1_out_root_mean_squared_error: 0.6040 - val_y2_out_root_mean_squared_error: 0.9130
# Epoch 475/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.6020 - y1_out_loss: 0.1369 - y2_out_loss: 0.4610 - y1_out_root_mean_squared_error: 0.3715 - y2_out_root_mean_squared_error: 0.6812 - val_loss: 0.7523 - val_y1_out_loss: 0.2827 - val_y2_out_loss: 0.4878 - val_y1_out_root_mean_squared_error: 0.5107 - val_y2_out_root_mean_squared_error: 0.7010
# Epoch 476/500
# 614/614 [==============================] - 0s 124us/sample - loss: 0.4136 - y1_out_loss: 0.1155 - y2_out_loss: 0.3087 - y1_out_root_mean_squared_error: 0.3341 - y2_out_root_mean_squared_error: 0.5495 - val_loss: 2.1504 - val_y1_out_loss: 0.5882 - val_y2_out_loss: 1.6433 - val_y1_out_root_mean_squared_error: 0.7660 - val_y2_out_root_mean_squared_error: 1.2504
# Epoch 477/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.7005 - y1_out_loss: 0.1524 - y2_out_loss: 0.5434 - y1_out_root_mean_squared_error: 0.3912 - y2_out_root_mean_squared_error: 0.7399 - val_loss: 0.8758 - val_y1_out_loss: 0.3190 - val_y2_out_loss: 0.5807 - val_y1_out_root_mean_squared_error: 0.5375 - val_y2_out_root_mean_squared_error: 0.7661
# Epoch 478/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.4836 - y1_out_loss: 0.1111 - y2_out_loss: 0.3722 - y1_out_root_mean_squared_error: 0.3334 - y2_out_root_mean_squared_error: 0.6103 - val_loss: 1.0057 - val_y1_out_loss: 0.3390 - val_y2_out_loss: 0.6720 - val_y1_out_root_mean_squared_error: 0.5614 - val_y2_out_root_mean_squared_error: 0.8309
# Epoch 479/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.5305 - y1_out_loss: 0.1417 - y2_out_loss: 0.3852 - y1_out_root_mean_squared_error: 0.3776 - y2_out_root_mean_squared_error: 0.6228 - val_loss: 0.7416 - val_y1_out_loss: 0.2925 - val_y2_out_loss: 0.4763 - val_y1_out_root_mean_squared_error: 0.5128 - val_y2_out_root_mean_squared_error: 0.6919
# Epoch 480/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.4497 - y1_out_loss: 0.1057 - y2_out_loss: 0.3443 - y1_out_root_mean_squared_error: 0.3253 - y2_out_root_mean_squared_error: 0.5864 - val_loss: 0.8163 - val_y1_out_loss: 0.2572 - val_y2_out_loss: 0.5532 - val_y1_out_root_mean_squared_error: 0.5029 - val_y2_out_root_mean_squared_error: 0.7506
# Epoch 481/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.4614 - y1_out_loss: 0.1062 - y2_out_loss: 0.3520 - y1_out_root_mean_squared_error: 0.3274 - y2_out_root_mean_squared_error: 0.5952 - val_loss: 0.9310 - val_y1_out_loss: 0.2958 - val_y2_out_loss: 0.6389 - val_y1_out_root_mean_squared_error: 0.5456 - val_y2_out_root_mean_squared_error: 0.7958
# Epoch 482/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.4832 - y1_out_loss: 0.1164 - y2_out_loss: 0.3654 - y1_out_root_mean_squared_error: 0.3403 - y2_out_root_mean_squared_error: 0.6061 - val_loss: 0.7529 - val_y1_out_loss: 0.2795 - val_y2_out_loss: 0.4830 - val_y1_out_root_mean_squared_error: 0.5133 - val_y2_out_root_mean_squared_error: 0.6996
# Epoch 483/500
# 614/614 [==============================] - 0s 123us/sample - loss: 0.3529 - y1_out_loss: 0.1025 - y2_out_loss: 0.2516 - y1_out_root_mean_squared_error: 0.3191 - y2_out_root_mean_squared_error: 0.5011 - val_loss: 1.0183 - val_y1_out_loss: 0.4128 - val_y2_out_loss: 0.6682 - val_y1_out_root_mean_squared_error: 0.5970 - val_y2_out_root_mean_squared_error: 0.8135
# Epoch 484/500
# 614/614 [==============================] - 0s 127us/sample - loss: 1.1411 - y1_out_loss: 0.2885 - y2_out_loss: 0.8432 - y1_out_root_mean_squared_error: 0.5394 - y2_out_root_mean_squared_error: 0.9220 - val_loss: 0.7926 - val_y1_out_loss: 0.2994 - val_y2_out_loss: 0.5061 - val_y1_out_root_mean_squared_error: 0.5291 - val_y2_out_root_mean_squared_error: 0.7160
# Epoch 485/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.4201 - y1_out_loss: 0.1168 - y2_out_loss: 0.3157 - y1_out_root_mean_squared_error: 0.3396 - y2_out_root_mean_squared_error: 0.5521 - val_loss: 1.7082 - val_y1_out_loss: 0.5534 - val_y2_out_loss: 1.2164 - val_y1_out_root_mean_squared_error: 0.6975 - val_y2_out_root_mean_squared_error: 1.1053
# Epoch 486/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.6089 - y1_out_loss: 0.1495 - y2_out_loss: 0.4565 - y1_out_root_mean_squared_error: 0.3880 - y2_out_root_mean_squared_error: 0.6770 - val_loss: 1.0490 - val_y1_out_loss: 0.3007 - val_y2_out_loss: 0.7674 - val_y1_out_root_mean_squared_error: 0.5359 - val_y2_out_root_mean_squared_error: 0.8728
# Epoch 487/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.4208 - y1_out_loss: 0.1084 - y2_out_loss: 0.3154 - y1_out_root_mean_squared_error: 0.3287 - y2_out_root_mean_squared_error: 0.5593 - val_loss: 1.6248 - val_y1_out_loss: 0.3670 - val_y2_out_loss: 1.3000 - val_y1_out_root_mean_squared_error: 0.5726 - val_y2_out_root_mean_squared_error: 1.1388
# Epoch 488/500
# 614/614 [==============================] - 0s 123us/sample - loss: 0.6809 - y1_out_loss: 0.1853 - y2_out_loss: 0.4924 - y1_out_root_mean_squared_error: 0.4319 - y2_out_root_mean_squared_error: 0.7032 - val_loss: 1.1535 - val_y1_out_loss: 0.3229 - val_y2_out_loss: 0.8368 - val_y1_out_root_mean_squared_error: 0.5658 - val_y2_out_root_mean_squared_error: 0.9129
# Epoch 489/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.4501 - y1_out_loss: 0.1079 - y2_out_loss: 0.3399 - y1_out_root_mean_squared_error: 0.3289 - y2_out_root_mean_squared_error: 0.5848 - val_loss: 0.8389 - val_y1_out_loss: 0.3215 - val_y2_out_loss: 0.5358 - val_y1_out_root_mean_squared_error: 0.5488 - val_y2_out_root_mean_squared_error: 0.7333
# Epoch 490/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.4302 - y1_out_loss: 0.1254 - y2_out_loss: 0.3019 - y1_out_root_mean_squared_error: 0.3553 - y2_out_root_mean_squared_error: 0.5513 - val_loss: 0.6785 - val_y1_out_loss: 0.2727 - val_y2_out_loss: 0.4082 - val_y1_out_root_mean_squared_error: 0.5162 - val_y2_out_root_mean_squared_error: 0.6419
# Epoch 491/500
# 614/614 [==============================] - 0s 123us/sample - loss: 0.3585 - y1_out_loss: 0.0903 - y2_out_loss: 0.2669 - y1_out_root_mean_squared_error: 0.3006 - y2_out_root_mean_squared_error: 0.5178 - val_loss: 0.6907 - val_y1_out_loss: 0.2495 - val_y2_out_loss: 0.4449 - val_y1_out_root_mean_squared_error: 0.4918 - val_y2_out_root_mean_squared_error: 0.6699
# Epoch 492/500
# 614/614 [==============================] - 0s 120us/sample - loss: 0.3541 - y1_out_loss: 0.0998 - y2_out_loss: 0.2612 - y1_out_root_mean_squared_error: 0.3149 - y2_out_root_mean_squared_error: 0.5049 - val_loss: 0.9211 - val_y1_out_loss: 0.3528 - val_y2_out_loss: 0.5605 - val_y1_out_root_mean_squared_error: 0.5980 - val_y2_out_root_mean_squared_error: 0.7506
# Epoch 493/500
# 614/614 [==============================] - 0s 124us/sample - loss: 0.4418 - y1_out_loss: 0.1227 - y2_out_loss: 0.3327 - y1_out_root_mean_squared_error: 0.3480 - y2_out_root_mean_squared_error: 0.5664 - val_loss: 3.1397 - val_y1_out_loss: 0.6247 - val_y2_out_loss: 2.5914 - val_y1_out_root_mean_squared_error: 0.7917 - val_y2_out_root_mean_squared_error: 1.5852
# Epoch 494/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.5752 - y1_out_loss: 0.1132 - y2_out_loss: 0.4681 - y1_out_root_mean_squared_error: 0.3365 - y2_out_root_mean_squared_error: 0.6797 - val_loss: 0.8363 - val_y1_out_loss: 0.3280 - val_y2_out_loss: 0.5272 - val_y1_out_root_mean_squared_error: 0.5484 - val_y2_out_root_mean_squared_error: 0.7318
# Epoch 495/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.4703 - y1_out_loss: 0.1157 - y2_out_loss: 0.3527 - y1_out_root_mean_squared_error: 0.3403 - y2_out_root_mean_squared_error: 0.5954 - val_loss: 0.9219 - val_y1_out_loss: 0.3470 - val_y2_out_loss: 0.5823 - val_y1_out_root_mean_squared_error: 0.5772 - val_y2_out_root_mean_squared_error: 0.7674
# Epoch 496/500
# 614/614 [==============================] - 0s 122us/sample - loss: 0.4763 - y1_out_loss: 0.1074 - y2_out_loss: 0.3656 - y1_out_root_mean_squared_error: 0.3287 - y2_out_root_mean_squared_error: 0.6068 - val_loss: 0.7096 - val_y1_out_loss: 0.2634 - val_y2_out_loss: 0.4513 - val_y1_out_root_mean_squared_error: 0.4997 - val_y2_out_root_mean_squared_error: 0.6782
# Epoch 497/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.4122 - y1_out_loss: 0.0992 - y2_out_loss: 0.3112 - y1_out_root_mean_squared_error: 0.3158 - y2_out_root_mean_squared_error: 0.5590 - val_loss: 0.7138 - val_y1_out_loss: 0.2992 - val_y2_out_loss: 0.4171 - val_y1_out_root_mean_squared_error: 0.5318 - val_y2_out_root_mean_squared_error: 0.6564
# Epoch 498/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.4803 - y1_out_loss: 0.1209 - y2_out_loss: 0.3583 - y1_out_root_mean_squared_error: 0.3465 - y2_out_root_mean_squared_error: 0.6002 - val_loss: 0.8823 - val_y1_out_loss: 0.2773 - val_y2_out_loss: 0.5939 - val_y1_out_root_mean_squared_error: 0.5172 - val_y2_out_root_mean_squared_error: 0.7841
# Epoch 499/500
# 614/614 [==============================] - 0s 122us/sample - loss: 0.4515 - y1_out_loss: 0.1211 - y2_out_loss: 0.3295 - y1_out_root_mean_squared_error: 0.3484 - y2_out_root_mean_squared_error: 0.5746 - val_loss: 1.1287 - val_y1_out_loss: 0.4551 - val_y2_out_loss: 0.7173 - val_y1_out_root_mean_squared_error: 0.6462 - val_y2_out_root_mean_squared_error: 0.8433
# Epoch 500/500
# 614/614 [==============================] - 0s 123us/sample - loss: 0.4893 - y1_out_loss: 0.1270 - y2_out_loss: 0.3585 - y1_out_root_mean_squared_error: 0.3578 - y2_out_root_mean_squared_error: 0.6011 - val_loss: 0.6791 - val_y1_out_loss: 0.2460 - val_y2_out_loss: 0.4323 - val_y1_out_root_mean_squared_error: 0.4911 - val_y2_out_root_mean_squared_error: 0.6617

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 34us/sample - loss: 0.6791 - y1_out_loss: 0.2376 - y2_out_loss: 0.4270 - y1_out_root_mean_squared_error: 0.4911 - y2_out_root_mean_squared_error: 0.6617
# Loss = 0.6790838775696693, Y1_loss = 0.23756945133209229, Y1_mse = 0.49111202359199524, Y2_loss = 0.4270336627960205, Y2_mse = 0.6617347598075867

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_out_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_out_root_mean_squared_error', title='Y2 RMSE', ylim=7)
